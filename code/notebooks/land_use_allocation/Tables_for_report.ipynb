# %%
import pandas as pd
import numpy as np
import math

# %%
popAustral = pd.read_csv('./TablesForReport/Austral_pop.csv')
empAustral = pd.read_csv('./TablesForReport/Austral_emp.csv')

popKempsCreek = pd.read_csv('./TablesForReport/KempsCreek_pop.csv')
empKempsCreek = pd.read_csv('./TablesForReport/KempsCreek_emp.csv')

popRossmore = pd.read_csv('./TablesForReport/Rossmore_pop.csv')
empRossmore = pd.read_csv('./TablesForReport/Rossmore_emp.csv')

# %%
popAustral.iloc[[0,1,3,4,5,6,7,8,9],1:] = popAustral.iloc[[0,1,3,4,5,6,7,8,9],1:].apply(lambda x: np.nan_to_num(x).astype(int))
popAustral.iloc[[2,10,11,12,13,14],1:] = popAustral.iloc[[2,10,11,12,13,14],1:].apply(lambda x: np.round(x,2).astype(str))
print(popAustral.to_latex(index=False))
# Out:
# \begin{tabular}{lllllll}
# \toprule
#               Austral &    E-15 & D1/2-15 &    E-10 & D1/2-10 &   Rest &  Total \\
# \midrule
#                  Area &     144 &     144 &     144 &     144 &    909 &   1485 \\
#              Pop 2016 &     301 &     301 &     301 &     301 &   1904 &   3110 \\
#       Pop per ha 2016 &    2.09 &    2.09 &    2.09 &    2.09 &   2.09 &   2.09 \\
#         Pop Build out &       0 &       0 &       0 &       0 &      0 &      0 \\
#                No TOD &    6691 &    6691 &    6691 &    6691 &  42284 &  69049 \\
#               One TOD &   66240 &     301 &     301 &     301 &   1904 &  69049 \\
#               Two TOD &   33270 &   33270 &     301 &     301 &   1904 &  69049 \\
#             Three TOD &   22281 &   22281 &   22281 &     301 &   1904 &  69049 \\
#              Four TOD &   16786 &   16786 &   16786 &   16786 &   1904 &  69049 \\
#  Pop per ha Build out &       0 &       0 &       0 &       0 &      0 &      0 \\
# ...

# %%
empAustral.iloc[[0,1,3,4,5,6,7,8,9],1:] = empAustral.iloc[[0,1,3,4,5,6,7,8,9],1:].apply(lambda x: np.nan_to_num(x).astype(int))
empAustral.iloc[[2,10,11,12,13,14],1:] = empAustral.iloc[[2,10,11,12,13,14],1:].apply(lambda x: np.round(x,2).astype(str))
print(empAustral.to_latex(index=False))
# Out:
# \begin{tabular}{lllllll}
# \toprule
#                Austral &    E-15 & D1/2-15 &   E-10 & D1/2-10 &   Rest &  Total \\
# \midrule
#                   Area &     144 &     144 &    144 &     144 &    909 &   1485 \\
#              Jobs 2016 &     122 &     122 &    122 &     122 &    770 &   1259 \\
#       Jobs per ha 2016 &    0.85 &    0.85 &   0.85 &    0.85 &   0.85 &   0.85 \\
#         Jobs Build out &       0 &       0 &      0 &       0 &      0 &      0 \\
#                 No TOD &    1761 &    1761 &   1761 &    1761 &  11134 &  18182 \\
#                One TOD &   17045 &     122 &    122 &     122 &    770 &  18182 \\
#                Two TOD &    8583 &    8583 &    122 &     122 &    770 &  18182 \\
#              Three TOD &    5763 &    5763 &   5763 &     122 &    770 &  18182 \\
#               Four TOD &    4352 &    4352 &   4352 &    4352 &    770 &  18182 \\
#  Jobs per ha Build out &       0 &       0 &      0 &       0 &      0 &      0 \\
# ...

# %%
popKempsCreek.iloc[[0,1,3,4,5,6,7,8,9],1:] = popKempsCreek.iloc[[0,1,3,4,5,6,7,8,9],1:].apply(lambda x: np.nan_to_num(x).astype(int))
popKempsCreek.iloc[[2,10,11,12,13,14],1:] = popKempsCreek.iloc[[2,10,11,12,13,14],1:].apply(lambda x: np.round(x,2).astype(str))
print(popKempsCreek.to_latex(index=False))
# Out:
# \begin{tabular}{lllllll}
# \toprule
#           Kemps Creek &   D-25 &   C-25 &   D-20 &   C-20 &  Rest & Total \\
# \midrule
#                  Area &    144 &    144 &    144 &    144 &   293 &   869 \\
#              Pop 2016 &    248 &    248 &    248 &    248 &   505 &  1498 \\
#       Pop per ha 2016 &   1.72 &   1.72 &   1.72 &   1.72 &  1.72 &  1.72 \\
#         Pop Build out &      0 &      0 &      0 &      0 &     0 &     0 \\
#                No TOD &   1389 &   1389 &   1389 &   1389 &  2825 &  8379 \\
#               One TOD &   7129 &    248 &    248 &    248 &   505 &  8379 \\
#               Two TOD &   3689 &   3689 &    248 &    248 &   505 &  8379 \\
#             Three TOD &   2542 &   2542 &   2542 &    248 &   505 &  8379 \\
#              Four TOD &   1968 &   1968 &   1968 &   1968 &   505 &  8379 \\
#  Pop per ha Build out &      0 &      0 &      0 &      0 &     0 &     0 \\
#                No TOD &   9.64 &   9.64 &   9.64 &   9.64 &  9.64 &  9.64 \\
# ...

# %%
empKempsCreek.iloc[[0,1,3,4,5,6,7,8,9],1:] = empKempsCreek.iloc[[0,1,3,4,5,6,7,8,9],1:].apply(lambda x: np.nan_to_num(x).astype(int))
empKempsCreek.iloc[[2,10,11,12,13,14],1:] = empKempsCreek.iloc[[2,10,11,12,13,14],1:].apply(lambda x: np.round(x,2).astype(str))
print(empKempsCreek.to_latex(index=False))
# Out:
# \begin{tabular}{lllllll}
# \toprule
#            Kemps Creek &   D-25 &  C-25 &  D-20 &  C-20 &  Rest & Total \\
# \midrule
#                   Area &    144 &   144 &   144 &   144 &   292 &   868 \\
#              Jobs 2016 &    108 &   108 &   108 &   108 &   219 &   652 \\
#       Jobs per ha 2016 &   0.75 &  0.75 &  0.75 &  0.75 &  0.75 &  0.75 \\
#         Jobs Build out &      0 &     0 &     0 &     0 &     0 &     0 \\
#                 No TOD &    416 &   416 &   416 &   416 &   847 &  2513 \\
#                One TOD &   1969 &   108 &   108 &   108 &   219 &  2513 \\
#                Two TOD &   1038 &  1038 &   108 &   108 &   219 &  2513 \\
#              Three TOD &    728 &   728 &   728 &   108 &   219 &  2513 \\
#               Four TOD &    573 &   573 &   573 &   573 &   219 &  2513 \\
#  Jobs per ha Build out &      0 &     0 &     0 &     0 &     0 &     0 \\
#                 No TOD &   2.89 &  2.89 &  2.89 &  2.89 &  2.89 &  2.89 \\
# ...

# %%
popRossmore.iloc[[0,1,3,4,5,6,7,8,9],1:] = popRossmore.iloc[[0,1,3,4,5,6,7,8,9],1:].apply(lambda x: np.nan_to_num(x).astype(int))
popRossmore.iloc[[2,10,11,12,13,14],1:] = popRossmore.iloc[[2,10,11,12,13,14],1:].apply(lambda x: np.round(x,2).astype(str))
print(popRossmore.to_latex(index=False))
# Out:
# \begin{tabular}{lllllll}
# \toprule
#              Rossmore &   D-15 &   C-15 &   D-10 &   C-10 &   Rest &  Total \\
# \midrule
#                  Area &    144 &    144 &    144 &    144 &    410 &    986 \\
#              Pop 2016 &    253 &    253 &    253 &    253 &    723 &   1739 \\
#       Pop per ha 2016 &   1.76 &   1.76 &   1.76 &   1.76 &   1.76 &   1.76 \\
#         Pop Build out &      0 &      0 &      0 &      0 &      0 &      0 \\
#                No TOD &   2035 &   2035 &   2035 &   2035 &   5801 &  13944 \\
#               One TOD &  12458 &    253 &    253 &    253 &    723 &  13944 \\
#               Two TOD &   6356 &   6356 &    253 &    253 &    723 &  13944 \\
#             Three TOD &   4322 &   4322 &   4322 &    253 &    723 &  13944 \\
#              Four TOD &   3305 &   3305 &   3305 &   3305 &    723 &  13944 \\
#  Pop per ha Build out &      0 &      0 &      0 &      0 &      0 &      0 \\
# ...

# %%
empRossmore.iloc[[0,1,3,4,5,6,7,8,9],1:] = empRossmore.iloc[[0,1,3,4,5,6,7,8,9],1:].apply(lambda x: np.nan_to_num(x).astype(int))
empRossmore.iloc[[2,10,11,12,13,14],1:] = empRossmore.iloc[[2,10,11,12,13,14],1:].apply(lambda x: np.round(x,2).astype(str))
print(empRossmore.to_latex(index=False))
# Out:
# \begin{tabular}{lllllll}
# \toprule
#               Rossmore &   D-15 &  C-15 &  D-10 &  C-10 &  Rest & Total \\
# \midrule
#                   Area &    144 &   144 &   144 &   144 &   410 &   986 \\
#              Jobs 2016 &     85 &    85 &    85 &    85 &   244 &   587 \\
#       Jobs per ha 2016 &    0.6 &   0.6 &   0.6 &   0.6 &   0.6 &   0.6 \\
#         Jobs Build out &      0 &     0 &     0 &     0 &     0 &     0 \\
#                 No TOD &    385 &   385 &   385 &   385 &  1097 &  2639 \\
#                One TOD &   2137 &    85 &    85 &    85 &   244 &  2639 \\
#                Two TOD &   1111 &  1111 &    85 &    85 &   244 &  2639 \\
#              Three TOD &    769 &   769 &   769 &    85 &   244 &  2639 \\
#               Four TOD &    598 &   598 &   598 &   598 &   244 &  2639 \\
#  Jobs per ha Build out &      0 &     0 &     0 &     0 &     0 &     0 \\
#                 No TOD &   2.68 &  2.68 &  2.68 &  2.68 &  2.68 &  2.68 \\
# ...

# %%
codcomp = pd.read_csv('CoD_Summary_Comparison.csv')
lctotals = pd.read_csv('./ControlTotals/LiverpoolCouncil_Pop_ControlTotals.csv')

# %%
print(codcomp.to_latex(index=False))
# Out:
# \begin{tabular}{lrrr}
# \toprule
#       Unnamed: 0 &  Precinct summary &  Growth area summary &  TZ aggregation \\
# \midrule
#          Austral &               NaN &                  NaN &             NaN \\
#  Population 2016 &            1312.0 &               1312.0 &          1312.0 \\
#  Population 2056 &           31826.0 &              31496.0 &         31562.0 \\
#        Jobs 2016 &             407.0 &                407.0 &           407.0 \\
#        Jobs 2056 &            9218.0 &              10702.0 &         11003.0 \\
#         Rossmore &               NaN &                  NaN &             NaN \\
#  Population 2016 &            2367.0 &               2367.0 &          2367.0 \\
#  Population 2056 &           22450.0 &              30323.0 &         39128.0 \\
#        Jobs 2016 &             819.0 &                819.0 &           819.0 \\
#        Jobs 2056 &            2726.0 &               3132.0 &          3169.0 \\
# ...

# %%
lctotals.columns = ['Locality','Population 2016', 'Population Build Out']
lctotals['Locality'] = lctotals['Locality'].str.title()
lctotals = lctotals.sort_values('Locality').reset_index(drop=True)
lctotals.head()
# Out:
#                      Locality  Population 2016  Population Build Out
# 0  Ashcroft - Mount Pritchard             4217                  4281
# 1                     Austral             3110                 69049
# 2              Badgerys Creek              213                   170
# 3                   Bringelly             1965                 14179
# 4                       Busby             4465                  4524

# %%
print(lctotals.to_latex(index=False))
# Out:
# \begin{tabular}{lrr}
# \toprule
#                        Locality &  Population 2016 &  Population Build Out \\
# \midrule
#      Ashcroft - Mount Pritchard &             4217 &                  4281 \\
#                         Austral &             3110 &                 69049 \\
#                  Badgerys Creek &              213 &                   170 \\
#                       Bringelly &             1965 &                 14179 \\
#                           Busby &             4465 &                  4524 \\
#                      Cartwright &             2459 &                  2711 \\
#                          Casula &            16390 &                 15877 \\
#                     Cecil Hills &             7296 &                  6583 \\
#                      Cecil Park &              332 &                  2908 \\
#                 Chipping Norton &             9282 &                  8768 \\
# ...

# %%
lgapop = pd.read_csv('./TablesForMiro/LGA_Pop.csv')
lgaemp = pd.read_csv('./TablesForMiro/LGA_Emp.csv')
dapop = pd.read_csv('./TablesForMiro/DA_Pop.csv')
daemp = pd.read_csv('./TablesForMiro/DA_Emp.csv')

# %%
math.isnan(lgapop['Fid 2016'][2])
# Out:
# True

# %%
lgapop['Fid 2016'] = lgapop['Fid 2016'].apply(lambda x: '' if math.isnan(x)==True else int(x))
lgapop['Fid 2036'] = lgapop['Fid 2036'].apply(lambda x: '' if math.isnan(x)==True else int(x))
lgapop['Fid 2041'] = lgapop['Fid 2041'].apply(lambda x: '' if math.isnan(x)==True else int(x))

# %%
print(lgapop.to_latex(index=False))
# Out:
# \begin{tabular}{lrlrlrlr}
# \toprule
#                       LGA &  CoD 2016 & Fid 2016 &  CoD 2036 & Fid 2036 &  CoD 2041 & Fid 2041 &  CoD 2056 \\
# \midrule
#             Blacktown (C) &    350788 &   347592 &    554368 &   505278 &    588354 &          &    686166 \\
#        Blue Mountains (C) &     78620 &    78707 &     81540 &    82844 &     83987 &          &     91749 \\
#            Botany Bay (C) &     48798 &          &     76804 &          &     81420 &          &     95951 \\
#               Burwood (A) &     39335 &    38495 &     58935 &    47244 &     63519 &          &     76542 \\
#                Camden (A) &     80099 &    80477 &    207176 &   233299 &    236668 &          &    323726 \\
#    Campbelltown (C) (NSW) &    162286 &   161408 &    221610 &   275778 &    237877 &          &    289532 \\
#            Canada Bay (A) &     92535 &    92382 &    122166 &   119858 &    129502 &          &    152067 \\
# ...

# %%
print(lgaemp.to_latex(index=False))
# Out:
# \begin{tabular}{lrrr}
# \toprule
#                       LGA &  CoD 2016 &  CoD 2041 &  CoD 2056 \\
# \midrule
#             Blacktown (C) &    127239 &    206314 &    247170 \\
#        Blue Mountains (C) &     21300 &     25282 &     28435 \\
#            Botany Bay (C) &     58826 &     75080 &     81096 \\
#               Burwood (A) &     19264 &     26878 &     31732 \\
#                Camden (A) &     29174 &     63488 &    100250 \\
#    Campbelltown (C) (NSW) &     57037 &     74795 &     90853 \\
#            Canada Bay (A) &     39196 &     60394 &     71289 \\
#  Canterbury-Bankstown (A) &    114230 &    146202 &    163895 \\
#            Cumberland (A) &     84351 &    113705 &    130579 \\
#             Fairfield (C) &     69320 &     94513 &    110524 \\
#         Georges River (A) &     49745 &     66788 &     75936 \\
#            Hawkesbury (C) &     28839 &     36604 &     42765 \\
#               Hornsby (A) &     48623 &     65141 &     75423 \\
# ...

# %%
print(dapop.to_latex(index=False))
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
#                              Locality &  CoD 2016 &  Fid 2016 &  CoD 2041 &  Fid 2041 &  CoD 2056 \\
# \midrule
#                               Austral &      2962 &      3110 &     25849 &     69049 &     49904 \\
#                            Cecil Park &       342 &       332 &      1961 &      1618 &      5147 \\
#                              Rossmore &      1789 &      1739 &     16013 &     13213 &     24678 \\
#                           Kemps Creek &      1541 &      1498 &     10718 &      8844 &     14829 \\
#                             Bringelly &      2022 &      1965 &     18476 &     15245 &     25093 \\
#  Badgerys Creek ((Incl. Aerotropolis) &       219 &       213 &       300 &       248 &       300 \\
#                   Luddenham (Airport) &       593 &       576 &       757 &       625 &       762 \\
#                             Greendale &       355 &       345 &       501 &       413 &       603 \\
# ...

# %%
print(daemp.to_latex(index=False))
# Out:
# \begin{tabular}{lrrr}
# \toprule
#                              Locality &  CoD 2016 &  CoD 2041 &  CoD 2056 \\
# \midrule
#                               Austral &      1259 &     11718 &     18182 \\
#                            Cecil Park &       310 &       405 &       525 \\
#                              Rossmore &       236 &       685 &      2200 \\
#                           Kemps Creek &       652 &      1864 &      2513 \\
#                             Bringelly &       202 &       898 &      2365 \\
#  Badgerys Creek ((Incl. Aerotropolis) &       221 &     25054 &     57151 \\
#                   Luddenham (Airport) &       100 &      8357 &     15302 \\
#                             Greendale &       387 &       885 &      1141 \\
#                              Wallacia &       159 &       195 &       214 \\
#                Development Area Total &      3526 &     50061 &     99593 \\
#               Liverpool Council Total &     80684 &    175088 &    258406 \\
# ...
